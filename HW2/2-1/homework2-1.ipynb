# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# read files from google drive
import os
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/NTU_MLDS_Spring2018/HW2'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
# print(os.listdir(GOOGLE_DRIVE_PATH))

# import modules from google drive
import sys
sys.path.append(GOOGLE_DRIVE_PATH)
# Out:
# Mounted at /content/drive

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2023-05-11 08:45:40.695320: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 08:45:41.708766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-11 08:45:43.078933: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %% [markdown]
# # Download dataset

# %%
# update gdown, if it failed to download large files
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...

# %%
# dataset for 2-1
# !gdown https://drive.google.com/uc?id=1RevHMfXZ1zYjUm4fPU1CfFKAjyMJjdgJ
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1RevHMfXZ1zYjUm4fPU1CfFKAjyMJjdgJ
# From (redirected): https://drive.google.com/uc?id=1RevHMfXZ1zYjUm4fPU1CfFKAjyMJjdgJ&confirm=t&uuid=9ddc1b83-429d-400b-b744-a4294c973d44
# To: /content/MLDS_hw2_1_data.tar.gz
# 100% 2.41G/2.41G [00:14<00:00, 165MB/s]

# %%
# !tar -zxf MLDS_hw2_1_data.tar.gz  # don't show the progress

# %% [markdown]
# # Training

# %%
# %cd $GOOGLE_DRIVE_PATH/2-1
# Out:
# /content/drive/My Drive/Colab Notebooks/NTU_MLDS_Spring2018/HW2/2-1

# %%
data_path = '/content/MLDS_hw2_1_data'

# %%
# id_file = '/content/MLDS_hw2_1_data/training_data/id.txt'
# feat_dir = '/content/MLDS_hw2_1_data/training_data/feat'
# label_file = '/content/MLDS_hw2_1_data/training_label.json'

# %%
# test_id_file = '/content/MLDS_hw2_1_data/testing_data/id.txt'
# test_feat_dir = '/content/MLDS_hw2_1_data/testing_data/feat'
test_label_file = '/content/MLDS_hw2_1_data/testing_label.json'

# %%
# executing for about 1.1 hr
# !python model_seq2seq.py --train_data $data_path --use_attention
# Out:
# 2023-05-11 08:46:55.555915: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 08:46:56.595847: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-11 08:46:57.974994: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %% [markdown]
# # Inference

# %% [markdown]
# Inference, and show one of original captions as reference.

# %%
# !bash ./hw2_seq2seq.sh $data_path 'caption_output.txt'
# Out:
# 2023-05-11 09:58:47.110456: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 09:58:48.155146: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-11 09:58:49.522955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %% [markdown]
# # Evaluation

# %% [markdown]
# Baseline: BLEU@1 = 0.6 (Captions Avg.)

# %%
# !python bleu_eval.py $test_label_file caption_output.txt
# Out:
# Average bleu score is 0.631262388186672
